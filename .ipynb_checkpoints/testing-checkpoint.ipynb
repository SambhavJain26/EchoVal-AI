# %%
import modal

# %%
# !modal setup
# Out:
# The web browser should have opened for you to authenticate and get an API
# token.
# If it didn't, please copy this URL into your web browser manually:
#
#
# The web browser should have opened for you to authenticate and get an API
# token.
# If it didn't, please copy this URL into your web browser manually:
# +- Error ---------------------------------------------------------------------+
# | 'charmap' codec can't encode character '\u2819' in position 0: character    |
# | maps to <undefined>                                                         |
# +-----------------------------------------------------------------------------+

# %%
import modal
from pricer_ephemeral import app, price

# %%
with modal.enable_output():
    with app.run():
        result=price.remote("Quadcast HyperX condenser mic, connects via usb-c to your computer for crystal clear audio")
result
# Out:
# Output()
# ✓ Initialized. View run at https://modal.com/apps/worksambhav26/main/ap-NU6ucWYmJbQ20i6JnaNhw3
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace"></pre>
# Output()
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace"></pre>
# ✓ Created objects.
# ├── 🔨 Created mount C:\Web Development\Projects\EchoVal AI\pricer_ephemeral.py
# └── 🔨 Created function price.
# Output()
# Fetching 5 files:   0%|          | 0/5 [00:00<?, ?it/s]
# Fetching 5 files:  20%|██        | 1/5 [01:02<04:10, 62.66s/it]
# Fetching 5 files:  40%|████      | 2/5 [01:03<01:18, 26.06s/it]Fetching 5 files: 100%|██████████| 5/5 [01:03<00:00, 12.62s/it]
# Loading checkpoint shards:   0%|          | 0/5 [00:00<?, ?it/s]
# Loading checkpoint shards:  20%|██        | 1/5 [00:03<00:13,  3.27s/it]
# Loading checkpoint shards:  40%|████      | 2/5 [00:07<00:10,  3.63s/it]
# Loading checkpoint shards:  60%|██████    | 3/5 [00:11<00:07,  3.74s/it]
# Loading checkpoint shards:  80%|████████  | 4/5 [00:14<00:03,  3.50s/it]
# Loading checkpoint shards: 100%|██████████| 5/5 [00:14<00:00,  2.37s/it]Loading checkpoint shards: 100%|██████████| 5/5 [00:14<00:00,  2.90s/it]
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace"><span style="color: #800000; text-decoration-color: #800000"></span></pre>
# /usr/local/lib/python3.11/site-packages/peft/peft_model.py:569: UserWarning: Found missing adapter keys while loading the checkpoint: ['base_model.model.model.layers.32.self_attn.q_proj.lora_A.default.weight', 'base_model.model.model.layers.32.self_attn.q_proj.lora_B.default.weight', 'base_model.model.model.layers.32.self_attn.k_proj.lora_A.default.weight', 'base_model.model.model.layers.32.self_attn.k_proj.lora_B.default.weight', 'base_model.model.model.layers.32.self_attn.v_proj.lora_A.default.weight', 'base_model.model.model.layers.32.self_attn.v_proj.lora_B.default.weight', 'base_model.model.model.layers.32.self_attn.o_proj.lora_A.default.weight', 'base_model.model.model.layers.32.self_attn.o_proj.lora_B.default.weight', 'base_model.model.model.layers.33.self_attn.q_proj.lora_A.default.weight', 'base_model.model.model.layers.33.self_attn.q_proj.lora_B.default.weight', 'base_model.model.model.layers.33.self_attn.k_proj.lora_A.default.weight', 'base_model.model.model.layers.33.self_attn.k_proj.lora_B.default.weight', 'base_model.model.model.layers.33.self_attn.v_proj.lora_A.default.weight', 'base_model.model.model.layers.33.self_attn.v_proj.lora_B.default.weight', 'base_model.model.model.layers.33.self_attn.o_proj.lora_A.default.weight', 'base_model.model.model.layers.33.self_attn.o_proj.lora_B.default.weight', 'base_model.model.model.layers.34.self_attn.q_proj.lora_A.default.weight', 'base_model.model.model.layers.34.self_attn.q_proj.lora_B.default.weight', 'base_model.model.model.layers.34.self_attn.k_proj.lora_A.default.weight', 'base_model.model.model.layers.34.self_attn.k_proj.lora_B.default.weight', 'base_model.model.model.layers.34.self_attn.v_proj.lora_A.default.weight', 'base_model.model.model.layers.34.self_attn.v_proj.lora_B.default.weight', 'base_model.model.model.layers.34.self_attn.o_proj.lora_A.default.weight', 'base_model.model.model.layers.34.self_attn.o_proj.lora_B.default.weight', 'base_model.model.model.layers.35.self_attn.q_proj.lora_A.default.weight', 'base_model.model.model.layers.35.self_attn.q_proj.lora_B.default.weight', 'base_model.model.model.layers.35.self_attn.k_proj.lora_A.default.weight', 'base_model.model.model.layers.35.self_attn.k_proj.lora_B.default.weight', 'base_model.model.model.layers.35.self_attn.v_proj.lora_A.default.weight', 'base_model.model.model.layers.35.self_attn.v_proj.lora_B.default.weight', 'base_model.model.model.layers.35.self_attn.o_proj.lora_A.default.weight', 'base_model.model.model.layers.35.self_attn.o_proj.lora_B.default.weight'].
#   warnings.warn(warn_message)
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace"></pre>
# Stopping app - local entrypoint completed.
# Runner terminated.
# ✓ App completed. View run at https://modal.com/apps/worksambhav26/main/ap-NU6ucWYmJbQ20i6JnaNhw3
# 139.9

# %%
import os
os.environ["PYTHONIOENCODING"] = "utf-8"

# %%
# !modal deploy -m pricer_service
# Out:
# - Creating objects...
# | Creating objects...
# / Creating objects...
# | Creating objects...
# â””â”€â”€ - Creating mount C:\Web Development\Projects\EchoVal AI\pricer_service.py:
#     Uploaded 0/1 files
# - Creating objects...
# â””â”€â”€ | Creating mount C:\Web Development\Projects\EchoVal AI\pricer_service.py:
#     Finalizing index of 1 files
# | Creating objects...
# â””â”€â”€ ðŸ”¨ Created mount C:\Web Development\Projects\EchoVal AI\pricer_service.py
# - Creating objects...
# â””â”€â”€ ðŸ”¨ Created mount C:\Web Development\Projects\EchoVal AI\pricer_service.py
# | Creating objects...
# â””â”€â”€ ðŸ”¨ Created mount C:\Web Development\Projects\EchoVal AI\pricer_service.py
# Building image im-fehIzfbszjgZAuOZATuf0E
# | Creating objects...
# â””â”€â”€ ðŸ”¨ Created mount C:\Web Development\Projects\EchoVal AI\pricer_service.py
#
# => Step 0: FROM base
# | Creating objects...
# â””â”€â”€ ðŸ”¨ Created mount C:\Web Development\Projects\EchoVal AI\pricer_service.py
#
# => Step 1: RUN python -m pip install accelerate bitsandbytes huggingface peft torch transformers
# | Creating objects...
# â””â”€â”€ ðŸ”¨ Created mount C:\Web Development\Projects\EchoVal AI\pricer_service.py
# - Creating objects...
# â””â”€â”€ ðŸ”¨ Created mount C:\Web Development\Projects\EchoVal AI\pricer_service.py
# | Creating objects...
# â””â”€â”€ ðŸ”¨ Created mount C:\Web Development\Projects\EchoVal AI\pricer_service.py
# - Creating objects...
# â””â”€â”€ ðŸ”¨ Created mount C:\Web Development\Projects\EchoVal AI\pricer_service.py
# Looking in indexes: http://pypi-mirror.modal.local:5555/simple
# \ Creating objects...
# â””â”€â”€ ðŸ”¨ Created mount C:\Web Development\Projects\EchoVal AI\pricer_service.py
# Collecting accelerate
# \ Creating objects...
# â””â”€â”€ ðŸ”¨ Created mount C:\Web Development\Projects\EchoVal AI\pricer_service.py
#   Downloading http://pypi-mirror.modal.local:5555/simple/accelerate/accelerate-1.7.0-py3-none-any.whl.metadata (19 kB)
# \ Creating objects...
# â””â”€â”€ ðŸ”¨ Created mount C:\Web Development\Projects\EchoVal AI\pricer_service.py
# | Creating objects...
# â””â”€â”€ ðŸ”¨ Created mount C:\Web Development\Projects\EchoVal AI\pricer_service.py
# Collecting bitsandbytes
# | Creating objects...
# â””â”€â”€ ðŸ”¨ Created mount C:\Web Development\Projects\EchoVal AI\pricer_service.py
#   Downloading http://pypi-mirror.modal.local:5555/simple/bitsandbytes/bitsandbytes-0.46.0-py3-none-manylinux_2_24_x86_64.whl.metadata (10 kB)
# | Creating objects...
# â””â”€â”€ ðŸ”¨ Created mount C:\Web Development\Projects\EchoVal AI\pricer_service.py
# Collecting huggingface
# | Creating objects...
# â””â”€â”€ ðŸ”¨ Created mount C:\Web Development\Projects\EchoVal AI\pricer_service.py
#   Downloading http://pypi-mirror.modal.local:5555/simple/huggingface/huggingface-0.0.1-py3-none-any.whl.metadata (2.9 kB)
# | Creating objects...
# â””â”€â”€ ðŸ”¨ Created mount C:\Web Development\Projects\EchoVal AI\pricer_service.py
# Collecting peft
# | Creating objects...
# â””â”€â”€ ðŸ”¨ Created mount C:\Web Development\Projects\EchoVal AI\pricer_service.py
#   Downloading http://pypi-mirror.modal.local:5555/simple/peft/peft-0.15.2-py3-none-any.whl.metadata (13 kB)
# | Creating objects...
# â””â”€â”€ ðŸ”¨ Created mount C:\Web Development\Projects\EchoVal AI\pricer_service.py
# Collecting torch
# / Creating objects...
# â””â”€â”€ ðŸ”¨ Created mount C:\Web Development\Projects\EchoVal AI\pricer_service.py
#   Downloading http://pypi-mirror.modal.local:5555/simple/torch/torch-2.7.0-cp311-cp311-manylinux_2_28_x86_64.whl.metadata (29 kB)
# / Creating objects...
# â””â”€â”€ ðŸ”¨ Created mount C:\Web Development\Projects\EchoVal AI\pricer_service.py
# - Creating objects...
# â””â”€â”€ ðŸ”¨ Created mount C:\Web Development\Projects\EchoVal AI\pricer_service.py
# Collecting transformers
# - Creating objects...
# â””â”€â”€ ðŸ”¨ Created mount C:\Web Development\Projects\EchoVal AI\pricer_service.py
#   Downloading http://pypi-mirror.modal.local:5555/simple/transformers/transformers-4.52.3-py3-none-any.whl.metadata (40 kB)
# - Creating objects...
# â””â”€â”€ ðŸ”¨ Created mount C:\Web Development\Projects\EchoVal AI\pricer_service.py
# | Creating objects...
# â””â”€â”€ ðŸ”¨ Created mount C:\Web Development\Projects\EchoVal AI\pricer_service.py
# Collecting numpy<3.0.0,>=1.17 (from accelerate)
# / Creating objects...
# â””â”€â”€ ðŸ”¨ Created mount C:\Web Development\Projects\EchoVal AI\pricer_service.py
#   Downloading http://pypi-mirror.modal.local:5555/simple/numpy/numpy-2.2.6-cp311-cp311-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (62 kB)
# / Creating objects...
# â””â”€â”€ ðŸ”¨ Created mount C:\Web Development\Projects\EchoVal AI\pricer_service.py
# Collecting packaging>=20.0 (from accelerate)
# - Creating objects...
# â””â”€â”€ ðŸ”¨ Created mount C:\Web Development\Projects\EchoVal AI\pricer_service.py
#   Downloading http://pypi-mirror.modal.local:5555/simple/packaging/packaging-25.0-py3-none-any.whl.metadata (3.3 kB)
# - Creating objects...
# â””â”€â”€ ðŸ”¨ Created mount C:\Web Development\Projects\EchoVal AI\pricer_service.py
# - Creating objects...
# â””â”€â”€ ðŸ”¨ Created mount C:\Web Development\Projects\EchoVal AI\pricer_service.py
# Collecting psutil (from accelerate)
# - Creating objects...
# â””â”€â”€ ðŸ”¨ Created mount C:\Web Development\Projects\EchoVal AI\pricer_service.py
#   Downloading http://pypi-mirror.modal.local:5555/simple/psutil/psutil-7.0.0-cp36-abi3-manylinux_2_12_x86_64.manylinux2010_x86_64.manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (22 kB)
# \ Creating objects...
# â””â”€â”€ ðŸ”¨ Created mount C:\Web Development\Projects\EchoVal AI\pricer_service.py
# Collecting pyyaml (from accelerate)
# \ Creating objects...
# â””â”€â”€ ðŸ”¨ Created mount C:\Web Development\Projects\EchoVal AI\pricer_service.py
#   Downloading http://pypi-mirror.modal.local:5555/simple/pyyaml/PyYAML-6.0.2-cp311-cp311-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (2.1 kB)
# \ Creating objects...
# â””â”€â”€ ðŸ”¨ Created mount C:\Web Development\Projects\EchoVal AI\pricer_service.py
# | Creating objects...
# â””â”€â”€ ðŸ”¨ Created mount C:\Web Development\Projects\EchoVal AI\pricer_service.py
# Collecting huggingface-hub>=0.21.0 (from accelerate)
# | Creating objects...
# â””â”€â”€ ðŸ”¨ Created mount C:\Web Development\Projects\EchoVal AI\pricer_service.py
#   Downloading http://pypi-mirror.modal.local:5555/simple/huggingface-hub/huggingface_hub-0.32.2-py3-none-any.whl.metadata (14 kB)
# | Creating objects...
# â””â”€â”€ ðŸ”¨ Created mount C:\Web Development\Projects\EchoVal AI\pricer_service.py
# Collecting safetensors>=0.4.3 (from accelerate)
# - Creating objects...
# â””â”€â”€ ðŸ”¨ Created mount C:\Web Development\Projects\EchoVal AI\pricer_service.py
# - Creating objects...
# â””â”€â”€ ðŸ”¨ Created mount C:\Web Development\Projects\EchoVal AI\pricer_service.py
#   Downloading http://pypi-mirror.modal.local:5555/simple/safetensors/safetensors-0.5.3-cp38-abi3-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (3.8 kB)
# - Creating objects...
# â””â”€â”€ ðŸ”¨ Created mount C:\Web Development\Projects\EchoVal AI\pricer_service.py
# Collecting tqdm (from peft)
# \ Creating objects...
# â””â”€â”€ ðŸ”¨ Created mount C:\Web Development\Projects\EchoVal AI\pricer_service.py
#   Downloading http://pypi-mirror.modal.local:5555/simple/tqdm/tqdm-4.67.1-py3-none-any.whl.metadata (57 kB)
# \ Creating objects...
# â””â”€â”€ ðŸ”¨ Created mount C:\Web Development\Projects\EchoVal AI\pricer_service.py
# Collecting filelock (from torch)
# \ Creating objects...
# â””â”€â”€ ðŸ”¨ Created mount C:\Web Development\Projects\EchoVal AI\pricer_service.py
#   Downloading http://pypi-mirror.modal.local:5555/simple/filelock/filelock-3.18.0-py3-none-any.whl.metadata (2.9 kB)
# \ Creating objects...
# â””â”€â”€ ðŸ”¨ Created mount C:\Web Development\Projects\EchoVal AI\pricer_service.py
# Requirement already satisfied: typing-extensions>=4.10.0 in /usr/local/lib/python3.11/site-packages (from torch) (4.12.2)
# \ Creating objects...
# â””â”€â”€ ðŸ”¨ Created mount C:\Web Development\Projects\EchoVal AI\pricer_service.py
# Collecting sympy>=1.13.3 (from torch)
# \ Creating objects...
# â””â”€â”€ ðŸ”¨ Created mount C:\Web Development\Projects\EchoVal AI\pricer_service.py
#   Downloading http://pypi-mirror.modal.local:5555/simple/sympy/sympy-1.14.0-py3-none-any.whl.metadata (12 kB)
# \ Creating objects...
# â””â”€â”€ ðŸ”¨ Created mount C:\Web Development\Projects\EchoVal AI\pricer_service.py
# Collecting networkx (from torch)
# | Creating objects...
# â””â”€â”€ ðŸ”¨ Created mount C:\Web Development\Projects\EchoVal AI\pricer_service.py
#   Downloading http://pypi-mirror.modal.local:5555/simple/networkx/networkx-3.5-py3-none-any.whl.metadata (6.3 kB)
# | Creating objects...
# â””â”€â”€ ðŸ”¨ Created mount C:\Web Development\Projects\EchoVal AI\pricer_service.py
# | Creating objects...
# â””â”€â”€ ðŸ”¨ Created mount C:\Web Development\Projects\EchoVal AI\pricer_service.py
# Collecting jinja2 (from torch)
# | Creating objects...
# â””â”€â”€ ðŸ”¨ Created mount C:\Web Development\Projects\EchoVal AI\pricer_service.py
#   Downloading http://pypi-mirror.modal.local:5555/simple/jinja2/jinja2-3.1.6-py3-none-any.whl.metadata (2.9 kB)
# | Creating objects...
# â””â”€â”€ ðŸ”¨ Created mount C:\Web Development\Projects\EchoVal AI\pricer_service.py
# Collecting fsspec (from torch)
# | Creating objects...
# â””â”€â”€ ðŸ”¨ Created mount C:\Web Development\Projects\EchoVal AI\pricer_service.py
#   Downloading http://pypi-mirror.modal.local:5555/simple/fsspec/fsspec-2025.5.1-py3-none-any.whl.metadata (11 kB)
# | Creating objects...
# â””â”€â”€ ðŸ”¨ Created mount C:\Web Development\Projects\EchoVal AI\pricer_service.py
# Collecting nvidia-cuda-nvrtc-cu12==12.6.77 (from torch)
# / Creating objects...
# â””â”€â”€ ðŸ”¨ Created mount C:\Web Development\Projects\EchoVal AI\pricer_service.py
#   Downloading http://pypi-mirror.modal.local:5555/simple/nvidia-cuda-nvrtc-cu12/nvidia_cuda_nvrtc_cu12-12.6.77-py3-none-manylinux2014_x86_64.whl.metadata (1.5 kB)
# / Creating objects...
# â””â”€â”€ ðŸ”¨ Created mount C:\Web Development\Projects\EchoVal AI\pricer_service.py
# Collecting nvidia-cuda-runtime-cu12==12.6.77 (from torch)
# / Creating objects...
# â””â”€â”€ ðŸ”¨ Created mount C:\Web Development\Projects\EchoVal AI\pricer_service.py
#   Downloading http://pypi-mirror.modal.local:5555/simple/nvidia-cuda-runtime-cu12/nvidia_cuda_runtime_cu12-12.6.77-py3-none-manylinux2014_x86_64.manylinux_2_17_x86_64.whl.metadata (1.5 kB)
# / Creating objects...
# â””â”€â”€ ðŸ”¨ Created mount C:\Web Development\Projects\EchoVal AI\pricer_service.py
# Collecting nvidia-cuda-cupti-cu12==12.6.80 (from torch)
# / Creating objects...
# â””â”€â”€ ðŸ”¨ Created mount C:\Web Development\Projects\EchoVal AI\pricer_service.py
#   Downloading http://pypi-mirror.modal.local:5555/simple/nvidia-cuda-cupti-cu12/nvidia_cuda_cupti_cu12-12.6.80-py3-none-manylinux2014_x86_64.manylinux_2_17_x86_64.whl.metadata (1.6 kB)
# / Creating objects...
# â””â”€â”€ ðŸ”¨ Created mount C:\Web Development\Projects\EchoVal AI\pricer_service.py
# Collecting nvidia-cudnn-cu12==9.5.1.17 (from torch)
# / Creating objects...
# â””â”€â”€ ðŸ”¨ Created mount C:\Web Development\Projects\EchoVal AI\pricer_service.py
#   Downloading http://pypi-mirror.modal.local:5555/simple/nvidia-cudnn-cu12/nvidia_cudnn_cu12-9.5.1.17-py3-none-manylinux_2_28_x86_64.whl.metadata (1.6 kB)
# - Creating objects...
# â””â”€â”€ ðŸ”¨ Created mount C:\Web Development\Projects\EchoVal AI\pricer_service.py
# Collecting nvidia-cublas-cu12==12.6.4.1 (from torch)
# - Creating objects...
# â””â”€â”€ ðŸ”¨ Created mount C:\Web Development\Projects\EchoVal AI\pricer_service.py
#   Downloading http://pypi-mirror.modal.local:5555/simple/nvidia-cublas-cu12/nvidia_cublas_cu12-12.6.4.1-py3-none-manylinux2014_x86_64.manylinux_2_17_x86_64.whl.metadata (1.5 kB)
# - Creating objects...
# â””â”€â”€ ðŸ”¨ Created mount C:\Web Development\Projects\EchoVal AI\pricer_service.py
# Collecting nvidia-cufft-cu12==11.3.0.4 (from torch)
# - Creating objects...
# â””â”€â”€ ðŸ”¨ Created mount C:\Web Development\Projects\EchoVal AI\pricer_service.py
# - Creating objects...
# â””â”€â”€ ðŸ”¨ Created mount C:\Web Development\Projects\EchoVal AI\pricer_service.py
#   Downloading http://pypi-mirror.modal.local:5555/simple/nvidia-cufft-cu12/nvidia_cufft_cu12-11.3.0.4-py3-none-manylinux2014_x86_64.manylinux_2_17_x86_64.whl.metadata (1.5 kB)
# - Creating objects...
# â””â”€â”€ ðŸ”¨ Created mount C:\Web Development\Projects\EchoVal AI\pricer_service.py
# Collecting nvidia-curand-cu12==10.3.7.77 (from torch)
# - Creating objects...
# â””â”€â”€ ðŸ”¨ Created mount C:\Web Development\Projects\EchoVal AI\pricer_service.py
#   Downloading http://pypi-mirror.modal.local:5555/simple/nvidia-curand-cu12/nvidia_curand_cu12-10.3.7.77-py3-none-manylinux2014_x86_64.manylinux_2_17_x86_64.whl.metadata (1.5 kB)
# - Creating objects...
# â””â”€â”€ ðŸ”¨ Created mount C:\Web Development\Projects\EchoVal AI\pricer_service.py
# Collecting nvidia-cusolver-cu12==11.7.1.2 (from torch)
# - Creating objects...
# â””â”€â”€ ðŸ”¨ Created mount C:\Web Development\Projects\EchoVal AI\pricer_service.py
#   Downloading http://pypi-mirror.modal.local:5555/simple/nvidia-cusolver-cu12/nvidia_cusolver_cu12-11.7.1.2-py3-none-manylinux2014_x86_64.manylinux_2_17_x86_64.whl.metadata (1.6 kB)
# \ Creating objects...
# â””â”€â”€ ðŸ”¨ Created mount C:\Web Development\Projects\EchoVal AI\pricer_service.py
# Collecting nvidia-cusparse-cu12==12.5.4.2 (from torch)
# \ Creating objects...
# â””â”€â”€ ðŸ”¨ Created mount C:\Web Development\Projects\EchoVal AI\pricer_service.py
#   Downloading http://pypi-mirror.modal.local:5555/simple/nvidia-cusparse-cu12/nvidia_cusparse_cu12-12.5.4.2-py3-none-manylinux2014_x86_64.manylinux_2_17_x86_64.whl.metadata (1.6 kB)
# \ Creating objects...
# â””â”€â”€ ðŸ”¨ Created mount C:\Web Development\Projects\EchoVal AI\pricer_service.py
# Collecting nvidia-cusparselt-cu12==0.6.3 (from torch)
# \ Creating objects...
# â””â”€â”€ ðŸ”¨ Created mount C:\Web Development\Projects\EchoVal AI\pricer_service.py
#   Downloading http://pypi-mirror.modal.local:5555/simple/nvidia-cusparselt-cu12/nvidia_cusparselt_cu12-0.6.3-py3-none-manylinux2014_x86_64.whl.metadata (6.8 kB)
# \ Creating objects...
# â””â”€â”€ ðŸ”¨ Created mount C:\Web Development\Projects\EchoVal AI\pricer_service.py
# Collecting nvidia-nccl-cu12==2.26.2 (from torch)
# \ Creating objects...
# â””â”€â”€ ðŸ”¨ Created mount C:\Web Development\Projects\EchoVal AI\pricer_service.py
#   Downloading http://pypi-mirror.modal.local:5555/simple/nvidia-nccl-cu12/nvidia_nccl_cu12-2.26.2-py3-none-manylinux2014_x86_64.manylinux_2_17_x86_64.whl.metadata (2.0 kB)
# \ Creating objects...
# â””â”€â”€ ðŸ”¨ Created mount C:\Web Development\Projects\EchoVal AI\pricer_service.py
# Collecting nvidia-nvtx-cu12==12.6.77 (from torch)
# \ Creating objects...
# â””â”€â”€ ðŸ”¨ Created mount C:\Web Development\Projects\EchoVal AI\pricer_service.py
#   Downloading http://pypi-mirror.modal.local:5555/simple/nvidia-nvtx-cu12/nvidia_nvtx_cu12-12.6.77-py3-none-manylinux2014_x86_64.manylinux_2_17_x86_64.whl.metadata (1.6 kB)
# \ Creating objects...
# â””â”€â”€ ðŸ”¨ Created mount C:\Web Development\Projects\EchoVal AI\pricer_service.py
# Collecting nvidia-nvjitlink-cu12==12.6.85 (from torch)
# \ Creating objects...
# â””â”€â”€ ðŸ”¨ Created mount C:\Web Development\Projects\EchoVal AI\pricer_service.py
#   Downloading http://pypi-mirror.modal.local:5555/simple/nvidia-nvjitlink-cu12/nvidia_nvjitlink_cu12-12.6.85-py3-none-manylinux2010_x86_64.manylinux_2_12_x86_64.whl.metadata (1.5 kB)
# \ Creating objects...
# â””â”€â”€ ðŸ”¨ Created mount C:\Web Development\Projects\EchoVal AI\pricer_service.py
# Collecting nvidia-cufile-cu12==1.11.1.6 (from torch)
# | Creating objects...
# â””â”€â”€ ðŸ”¨ Created mount C:\Web Development\Projects\EchoVal AI\pricer_service.py
#   Downloading http://pypi-mirror.modal.local:5555/simple/nvidia-cufile-cu12/nvidia_cufile_cu12-1.11.1.6-py3-none-manylinux2014_x86_64.manylinux_2_17_x86_64.whl.metadata (1.5 kB)
# | Creating objects...
# â””â”€â”€ ðŸ”¨ Created mount C:\Web Development\Projects\EchoVal AI\pricer_service.py
# Collecting triton==3.3.0 (from torch)
# | Creating objects...
# â””â”€â”€ ðŸ”¨ Created mount C:\Web Development\Projects\EchoVal AI\pricer_service.py
#   Downloading http://pypi-mirror.modal.local:5555/simple/triton/triton-3.3.0-cp311-cp311-manylinux_2_27_x86_64.manylinux_2_28_x86_64.whl.metadata (1.5 kB)
# | Creating objects...
# â””â”€â”€ ðŸ”¨ Created mount C:\Web Development\Projects\EchoVal AI\pricer_service.py
# Requirement already satisfied: setuptools>=40.8.0 in /usr/local/lib/python3.11/site-packages (from triton==3.3.0->torch) (65.5.1)
# | Creating objects...
# â””â”€â”€ ðŸ”¨ Created mount C:\Web Development\Projects\EchoVal AI\pricer_service.py
# | Creating objects...
# â””â”€â”€ ðŸ”¨ Created mount C:\Web Development\Projects\EchoVal AI\pricer_service.py
# - Creating objects...
# â””â”€â”€ ðŸ”¨ Created mount C:\Web Development\Projects\EchoVal AI\pricer_service.py
# Collecting regex!=2019.12.17 (from transformers)
# | Creating objects...
# â””â”€â”€ ðŸ”¨ Created mount C:\Web Development\Projects\EchoVal AI\pricer_service.py
# | Creating objects...
# â””â”€â”€ ðŸ”¨ Created mount C:\Web Development\Projects\EchoVal AI\pricer_service.py
#   Downloading http://pypi-mirror.modal.local:5555/simple/regex/regex-2024.11.6-cp311-cp311-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (40 kB)
# | Creating objects...
# â””â”€â”€ ðŸ”¨ Created mount C:\Web Development\Projects\EchoVal AI\pricer_service.py
# Collecting requests (from transformers)
# | Creating objects...
# â””â”€â”€ ðŸ”¨ Created mount C:\Web Development\Projects\EchoVal AI\pricer_service.py
#   Downloading http://pypi-mirror.modal.local:5555/simple/requests/requests-2.32.3-py3-none-any.whl.metadata (4.6 kB)
# | Creating objects...
# â””â”€â”€ ðŸ”¨ Created mount C:\Web Development\Projects\EchoVal AI\pricer_service.py
# - Creating objects...
# â””â”€â”€ ðŸ”¨ Created mount C:\Web Development\Projects\EchoVal AI\pricer_service.py
# Collecting tokenizers<0.22,>=0.21 (from transformers)
# - Creating objects...
# â””â”€â”€ ðŸ”¨ Created mount C:\Web Development\Projects\EchoVal AI\pricer_service.py
#   Downloading http://pypi-mirror.modal.local:5555/simple/tokenizers/tokenizers-0.21.1-cp39-abi3-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (6.8 kB)
# - Creating objects...
# â””â”€â”€ ðŸ”¨ Created mount C:\Web Development\Projects\EchoVal AI\pricer_service.py
# Collecting hf-xet<2.0.0,>=1.1.2 (from huggingface-hub>=0.21.0->accelerate)
# \ Creating objects...
# â””â”€â”€ ðŸ”¨ Created mount C:\Web Development\Projects\EchoVal AI\pricer_service.py
#   Downloading http://pypi-mirror.modal.local:5555/simple/hf-xet/hf_xet-1.1.2-cp37-abi3-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (879 bytes)
# \ Creating objects...
# â””â”€â”€ ðŸ”¨ Created mount C:\Web Development\Projects\EchoVal AI\pricer_service.py
# Collecting mpmath<1.4,>=1.1.0 (from sympy>=1.13.3->torch)
# \ Creating objects...
# â””â”€â”€ ðŸ”¨ Created mount C:\Web Development\Projects\EchoVal AI\pricer_service.py
#   Downloading http://pypi-mirror.modal.local:5555/simple/mpmath/mpmath-1.3.0-py3-none-any.whl.metadata (8.6 kB)
# \ Creating objects...
# â””â”€â”€ ðŸ”¨ Created mount C:\Web Development\Projects\EchoVal AI\pricer_service.py
# Collecting MarkupSafe>=2.0 (from jinja2->torch)
# | Creating objects...
# â””â”€â”€ ðŸ”¨ Created mount C:\Web Development\Projects\EchoVal AI\pricer_service.py
#   Downloading http://pypi-mirror.modal.local:5555/simple/markupsafe/MarkupSafe-3.0.2-cp311-cp311-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (4.0 kB)
# | Creating objects...
# â””â”€â”€ ðŸ”¨ Created mount C:\Web Development\Projects\EchoVal AI\pricer_service.py
# | Creating objects...
# â””â”€â”€ ðŸ”¨ Created mount C:\Web Development\Projects\EchoVal AI\pricer_service.py
# Collecting charset-normalizer<4,>=2 (from requests->transformers)
# / Creating objects...
# â””â”€â”€ ðŸ”¨ Created mount C:\Web Development\Projects\EchoVal AI\pricer_service.py
#   Downloading http://pypi-mirror.modal.local:5555/simple/charset-normalizer/charset_normalizer-3.4.2-cp311-cp311-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (35 kB)
# / Creating objects...
# â””â”€â”€ ðŸ”¨ Created mount C:\Web Development\Projects\EchoVal AI\pricer_service.py
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.11/site-packages (from requests->transformers) (3.10)
# / Creating objects...
# â””â”€â”€ ðŸ”¨ Created mount C:\Web Development\Projects\EchoVal AI\pricer_service.py
# Collecting urllib3<3,>=1.21.1 (from requests->transformers)
# / Creating objects...
# â””â”€â”€ ðŸ”¨ Created mount C:\Web Development\Projects\EchoVal AI\pricer_service.py
#   Downloading http://pypi-mirror.modal.local:5555/simple/urllib3/urllib3-2.4.0-py3-none-any.whl.metadata (6.5 kB)
# / Creating objects...
# â””â”€â”€ ðŸ”¨ Created mount C:\Web Development\Projects\EchoVal AI\pricer_service.py
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.11/site-packages (from requests->transformers) (2024.8.30)
# / Creating objects...
# â””â”€â”€ ðŸ”¨ Created mount C:\Web Development\Projects\EchoVal AI\pricer_service.py
# Downloading http://pypi-mirror.modal.local:5555/simple/accelerate/accelerate-1.7.0-py3-none-any.whl (362 kB)
# - Creating objects...
# â””â”€â”€ ðŸ”¨ Created mount C:\Web Development\Projects\EchoVal AI\pricer_service.py
# Downloading http://pypi-mirror.modal.local:5555/simple/bitsandbytes/bitsandbytes-0.46.0-py3-none-manylinux_2_24_x86_64.whl (67.0 MB)
# - Creating objects...
# â””â”€â”€ ðŸ”¨ Created mount C:\Web Development\Projects\EchoVal AI\pricer_service.py
# - Creating objects...
# â””â”€â”€ ðŸ”¨ Created mount C:\Web Development\Projects\EchoVal AI\pricer_service.py
# | Creating objects...
# â””â”€â”€ ðŸ”¨ Created mount C:\Web Development\Projects\EchoVal AI\pricer_service.py
# | Creating objects...
# â””â”€â”€ ðŸ”¨ Created mount C:\Web Development\Projects\EchoVal AI\pricer_service.py
#    â”�â”�â”�â”�â”�â”�â”�â”�â”�â”�â”�â”�â”�â”�â”�â”�â”�â”�â”�â”�â”�â”�â”�â”�â”�â”�â”�â”�â”�â”�â”�â”�â”�â”�â”�â”�â”�â”�â”�â”� 67.0/67.0 MB 221.0 MB/s eta 0:00:00
# | Creating objects...
# â””â”€â”€ ðŸ”¨ Created mount C:\Web Development\Projects\EchoVal AI\pricer_service.py
# Downloading http://pypi-mirror.modal.local:5555/simple/huggingface/huggingface-0.0.1-py3-none-any.whl (2.5 kB)
# | Creating objects...
# â””â”€â”€ ðŸ”¨ Created mount C:\Web Development\Projects\EchoVal AI\pricer_service.py
# Downloading http://pypi-mirror.modal.local:5555/simple/peft/peft-0.15.2-py3-none-any.whl (411 kB)
# | Creating objects...
# â””â”€â”€ ðŸ”¨ Created mount C:\Web Development\Projects\EchoVal AI\pricer_service.py
# Downloading http://pypi-mirror.modal.local:5555/simple/torch/torch-2.7.0-cp311-cp311-manylinux_2_28_x86_64.whl (865.2 MB)
# / Creating objects...
# â””â”€â”€ ðŸ”¨ Created mount C:\Web Development\Projects\EchoVal AI\pricer_service.py
# - Creating objects...
# â””â”€â”€ ðŸ”¨ Created mount C:\Web Development\Projects\EchoVal AI\pricer_service.py
# | Creating objects...
# â””â”€â”€ ðŸ”¨ Created mount C:\Web Development\Projects\EchoVal AI\pricer_service.py
# - Creating objects...
# â””â”€â”€ ðŸ”¨ Created mount C:\Web Development\Projects\EchoVal AI\pricer_service.py
# | Creating objects...
# â””â”€â”€ ðŸ”¨ Created mount C:\Web Development\Projects\EchoVal AI\pricer_service.py
# - Creating objects...
# â””â”€â”€ ðŸ”¨ Created mount C:\Web Development\Projects\EchoVal AI\pricer_service.py
# | Creating objects...
# â””â”€â”€ ðŸ”¨ Created mount C:\Web Development\Projects\EchoVal AI\pricer_service.py
# - Creating objects...
# â””â”€â”€ ðŸ”¨ Created mount C:\Web Development\Projects\EchoVal AI\pricer_service.py
# | Creating objects...
# â””â”€â”€ ðŸ”¨ Created mount C:\Web Development\Projects\EchoVal AI\pricer_service.py
# - Creating objects...
# â””â”€â”€ ðŸ”¨ Created mount C:\Web Development\Projects\EchoVal AI\pricer_service.py
# | Creating objects...
# â””â”€â”€ ðŸ”¨ Created mount C:\Web Development\Projects\EchoVal AI\pricer_service.py
# - Creating objects...
# â””â”€â”€ ðŸ”¨ Created mount C:\Web Development\Projects\EchoVal AI\pricer_service.py
# | Creating objects...
# â””â”€â”€ ðŸ”¨ Created mount C:\Web Development\Projects\EchoVal AI\pricer_service.py
# - Creating objects...
# â””â”€â”€ ðŸ”¨ Created mount C:\Web Development\Projects\EchoVal AI\pricer_service.py
# | Creating objects...
# â””â”€â”€ ðŸ”¨ Created mount C:\Web Development\Projects\EchoVal AI\pricer_service.py
# \ Creating objects...
# â””â”€â”€ ðŸ”¨ Created mount C:\Web Development\Projects\EchoVal AI\pricer_service.py
# | Creating objects...
# â””â”€â”€ ðŸ”¨ Created mount C:\Web Development\Projects\EchoVal AI\pricer_service.py
# / Creating objects...
# â””â”€â”€ ðŸ”¨ Created mount C:\Web Development\Projects\EchoVal AI\pricer_service.py
#    â”�â”�â”�â”�â”�â”�â”�â”�â”�â”�â”�â”�â”�â”�â”�â”�â”�â”�â”�â”�â”�â”�â”�â”�â”�â”�â”�â”�â”�â”�â”�â”�â”�â”�â”�â”�â”�â”�â”� 865.2/865.2 MB 225.1 MB/s eta 0:00:00
# / Creating objects...
# â””â”€â”€ ðŸ”¨ Created mount C:\Web Development\Projects\EchoVal AI\pricer_service.py
# Downloading http://pypi-mirror.modal.local:5555/simple/nvidia-cublas-cu12/nvidia_cublas_cu12-12.6.4.1-py3-none-manylinux2014_x86_64.manylinux_2_17_x86_64.whl (393.1 MB)
# / Creating objects...
# â””â”€â”€ ðŸ”¨ Created mount C:\Web Development\Projects\EchoVal AI\pricer_service.py
# - Creating objects...
# â””â”€â”€ ðŸ”¨ Created mount C:\Web Development\Projects\EchoVal AI\pricer_service.py
# | Creating objects...
# â””â”€â”€ ðŸ”¨ Created mount C:\Web Development\Projects\EchoVal AI\pricer_service.py
# - Creating objects...
# â””â”€â”€ ðŸ”¨ Created mount C:\Web Development\Projects\EchoVal AI\pricer_service.py
# | Creating objects...
# â””â”€â”€ ðŸ”¨ Created mount C:\Web Development\Projects\EchoVal AI\pricer_service.py
# \ Creating objects...
# â””â”€â”€ ðŸ”¨ Created mount C:\Web Development\Projects\EchoVal AI\pricer_service.py
# / Creating objects...
# â””â”€â”€ ðŸ”¨ Created mount C:\Web Development\Projects\EchoVal AI\pricer_service.py
# / Creating objects...
# â””â”€â”€ ðŸ”¨ Created mount C:\Web Development\Projects\EchoVal AI\pricer_service.py
#    â”�â”�â”�â”�â”�â”�â”�â”�â”�â”�â”�â”�â”�â”�â”�â”�â”�â”�â”�â”�â”�â”�â”�â”�â”�â”�â”�â”�â”�â”�â”�â”�â”�â”�â”�â”�â”�â”�â”� 393.1/393.1 MB 245.7 MB/s eta 0:00:00
# / Creating objects...
# â””â”€â”€ ðŸ”¨ Created mount C:\Web Development\Projects\EchoVal AI\pricer_service.py
# Downloading http://pypi-mirror.modal.local:5555/simple/nvidia-cuda-cupti-cu12/nvidia_cuda_cupti_cu12-12.6.80-py3-none-manylinux2014_x86_64.manylinux_2_17_x86_64.whl (8.9 MB)
# / Creating objects...
# â””â”€â”€ ðŸ”¨ Created mount C:\Web Development\Projects\EchoVal AI\pricer_service.py
# - Creating objects...
# â””â”€â”€ ðŸ”¨ Created mount C:\Web Development\Projects\EchoVal AI\pricer_service.py
#    â”�â”�â”�â”�â”�â”�â”�â”�â”�â”�â”�â”�â”�â”�â”�â”�â”�â”�â”�â”�â”�â”�â”�â”�â”�â”�â”�â”�â”�â”�â”�â”�â”�â”�â”�â”�â”�â”�â”�â”� 8.9/8.9 MB 210.6 MB/s eta 0:00:00
# - Creating objects...
# â””â”€â”€ ðŸ”¨ Created mount C:\Web Development\Projects\EchoVal AI\pricer_service.py
# Downloading http://pypi-mirror.modal.local:5555/simple/nvidia-cuda-nvrtc-cu12/nvidia_cuda_nvrtc_cu12-12.6.77-py3-none-manylinux2014_x86_64.whl (23.7 MB)
# - Creating objects...
# â””â”€â”€ ðŸ”¨ Created mount C:\Web Development\Projects\EchoVal AI\pricer_service.py
# - Creating objects...
# â””â”€â”€ ðŸ”¨ Created mount C:\Web Development\Projects\EchoVal AI\pricer_service.py
#    â”�â”�â”�â”�â”�â”�â”�â”�â”�â”�â”�â”�â”�â”�â”�â”�â”�â”�â”�â”�â”�â”�â”�â”�â”�â”�â”�â”�â”�â”�â”�â”�â”�â”�â”�â”�â”�â”�â”�â”� 23.7/23.7 MB 230.9 MB/s eta 0:00:00
# - Creating objects...
# â””â”€â”€ ðŸ”¨ Created mount C:\Web Development\Projects\EchoVal AI\pricer_service.py
# Downloading http://pypi-mirror.modal.local:5555/simple/nvidia-cuda-runtime-cu12/nvidia_cuda_runtime_cu12-12.6.77-py3-none-manylinux2014_x86_64.manylinux_2_17_x86_64.whl (897 kB)
# - Creating objects...
# â””â”€â”€ ðŸ”¨ Created mount C:\Web Development\Projects\EchoVal AI\pricer_service.py
# - Creating objects...
# â””â”€â”€ ðŸ”¨ Created mount C:\Web Development\Projects\EchoVal AI\pricer_service.py
#    â”�â”�â”�â”�â”�â”�â”�â”�â”�â”�â”�â”�â”�â”�â”�â”�â”�â”�â”�â”�â”�â”�â”�â”�â”�â”�â”�â”�â”�â”�â”�â”�â”�â”�â”�â”�â”�â”�â”� 897.7/897.7 kB 349.2 MB/s eta 0:00:00
# - Creating objects...
# â””â”€â”€ ðŸ”¨ Created mount C:\Web Development\Projects\EchoVal AI\pricer_service.py
# Downloading http://pypi-mirror.modal.local:5555/simple/nvidia-cudnn-cu12/nvidia_cudnn_cu12-9.5.1.17-py3-none-manylinux_2_28_x86_64.whl (571.0 MB)
# - Creating objects...
# â””â”€â”€ ðŸ”¨ Created mount C:\Web Development\Projects\EchoVal AI\pricer_service.py
# \ Creating objects...
# â””â”€â”€ ðŸ”¨ Created mount C:\Web Development\Projects\EchoVal AI\pricer_service.py
# / Creating objects...
# â””â”€â”€ ðŸ”¨ Created mount C:\Web Development\Projects\EchoVal AI\pricer_service.py
# \ Creating objects...
# â””â”€â”€ ðŸ”¨ Created mount C:\Web Development\Projects\EchoVal AI\pricer_service.py
# / Creating objects...
# â””â”€â”€ ðŸ”¨ Created mount C:\Web Development\Projects\EchoVal AI\pricer_service.py
# \ Creating objects...
# â””â”€â”€ ðŸ”¨ Created mount C:\Web Development\Projects\EchoVal AI\pricer_service.py
# / Creating objects...
# â””â”€â”€ ðŸ”¨ Created mount C:\Web Development\Projects\EchoVal AI\pricer_service.py
# \ Creating objects...
# â””â”€â”€ ðŸ”¨ Created mount C:\Web Development\Projects\EchoVal AI\pricer_service.py
# / Creating objects...
# â””â”€â”€ ðŸ”¨ Created mount C:\Web Development\Projects\EchoVal AI\pricer_service.py
# \ Creating objects...
# â””â”€â”€ ðŸ”¨ Created mount C:\Web Development\Projects\EchoVal AI\pricer_service.py
# | Creating objects...
# â””â”€â”€ ðŸ”¨ Created mount C:\Web Development\Projects\EchoVal AI\pricer_service.py
#    â”�â”�â”�â”�â”�â”�â”�â”�â”�â”�â”�â”�â”�â”�â”�â”�â”�â”�â”�â”�â”�â”�â”�â”�â”�â”�â”�â”�â”�â”�â”�â”�â”�â”�â”�â”�â”�â”�â”� 571.0/571.0 MB 253.1 MB/s eta 0:00:00
# / Creating objects...
# â””â”€â”€ ðŸ”¨ Created mount C:\Web Development\Projects\EchoVal AI\pricer_service.py
# Downloading http://pypi-mirror.modal.local:5555/simple/nvidia-cufft-cu12/nvidia_cufft_cu12-11.3.0.4-py3-none-manylinux2014_x86_64.manylinux_2_17_x86_64.whl (200.2 MB)
# / Creating objects...
# â””â”€â”€ ðŸ”¨ Created mount C:\Web Development\Projects\EchoVal AI\pricer_service.py
# / Creating objects...
# â””â”€â”€ ðŸ”¨ Created mount C:\Web Development\Projects\EchoVal AI\pricer_service.py
# \ Creating objects...
# â””â”€â”€ ðŸ”¨ Created mount C:\Web Development\Projects\EchoVal AI\pricer_service.py
# / Creating objects...
# â””â”€â”€ ðŸ”¨ Created mount C:\Web Development\Projects\EchoVal AI\pricer_service.py
# \ Creating objects...
# â””â”€â”€ ðŸ”¨ Created mount C:\Web Development\Projects\EchoVal AI\pricer_service.py
# \ Creating objects...
# â””â”€â”€ ðŸ”¨ Created mount C:\Web Development\Projects\EchoVal AI\pricer_service.py
#    â”�â”�â”�â”�â”�â”�â”�â”�â”�â”�â”�â”�â”�â”�â”�â”�â”�â”�â”�â”�â”�â”�â”�â”�â”�â”�â”�â”�â”�â”�â”�â”�â”�â”�â”�â”�â”�â”�â”� 200.2/200.2 MB 245.0 MB/s eta 0:00:00
# \ Creating objects...
# â””â”€â”€ ðŸ”¨ Created mount C:\Web Development\Projects\EchoVal AI\pricer_service.py
# Downloading http://pypi-mirror.modal.local:5555/simple/nvidia-cufile-cu12/nvidia_cufile_cu12-1.11.1.6-py3-none-manylinux2014_x86_64.manylinux_2_17_x86_64.whl (1.1 MB)
# \ Creating objects...
# â””â”€â”€ ðŸ”¨ Created mount C:\Web Development\Projects\EchoVal AI\pricer_service.py
# \ Creating objects...
# â””â”€â”€ ðŸ”¨ Created mount C:\Web Development\Projects\EchoVal AI\pricer_service.py
#    â”�â”�â”�â”�â”�â”�â”�â”�â”�â”�â”�â”�â”�â”�â”�â”�â”�â”�â”�â”�â”�â”�â”�â”�â”�â”�â”�â”�â”�â”�â”�â”�â”�â”�â”�â”�â”�â”�â”�â”� 1.1/1.1 MB 149.6 MB/s eta 0:00:00
# \ Creating objects...
# â””â”€â”€ ðŸ”¨ Created mount C:\Web Development\Projects\EchoVal AI\pricer_service.py
# Downloading http://pypi-mirror.modal.local:5555/simple/nvidia-curand-cu12/nvidia_curand_cu12-10.3.7.77-py3-none-manylinux2014_x86_64.manylinux_2_17_x86_64.whl (56.3 MB)
# \ Creating objects...
# â””â”€â”€ ðŸ”¨ Created mount C:\Web Development\Projects\EchoVal AI\pricer_service.py
# / Creating objects...
# â””â”€â”€ ðŸ”¨ Created mount C:\Web Development\Projects\EchoVal AI\pricer_service.py
# / Creating objects...
# â””â”€â”€ ðŸ”¨ Created mount C:\Web Development\Projects\EchoVal AI\pricer_service.py
#    â”�â”�â”�â”�â”�â”�â”�â”�â”�â”�â”�â”�â”�â”�â”�â”�â”�â”�â”�â”�â”�â”�â”�â”�â”�â”�â”�â”�â”�â”�â”�â”�â”�â”�â”�â”�â”�â”�â”�â”� 56.3/56.3 MB 220.3 MB/s eta 0:00:00
# / Creating objects...
# â””â”€â”€ ðŸ”¨ Created mount C:\Web Development\Projects\EchoVal AI\pricer_service.py
# Downloading http://pypi-mirror.modal.local:5555/simple/nvidia-cusolver-cu12/nvidia_cusolver_cu12-11.7.1.2-py3-none-manylinux2014_x86_64.manylinux_2_17_x86_64.whl (158.2 MB)
# - Creating objects...
# â””â”€â”€ ðŸ”¨ Created mount C:\Web Development\Projects\EchoVal AI\pricer_service.py
# \ Creating objects...
# â””â”€â”€ ðŸ”¨ Created mount C:\Web Development\Projects\EchoVal AI\pricer_service.py
# / Creating objects...
# â””â”€â”€ ðŸ”¨ Created mount C:\Web Development\Projects\EchoVal AI\pricer_service.py
# - Creating objects...
# â””â”€â”€ ðŸ”¨ Created mount C:\Web Development\Projects\EchoVal AI\pricer_service.py
#    â”�â”�â”�â”�â”�â”�â”�â”�â”�â”�â”�â”�â”�â”�â”�â”�â”�â”�â”�â”�â”�â”�â”�â”�â”�â”�â”�â”�â”�â”�â”�â”�â”�â”�â”�â”�â”�â”�â”� 158.2/158.2 MB 235.0 MB/s eta 0:00:00
# - Creating objects...
# â””â”€â”€ ðŸ”¨ Created mount C:\Web Development\Projects\EchoVal AI\pricer_service.py
# Downloading http://pypi-mirror.modal.local:5555/simple/nvidia-cusparse-cu12/nvidia_cusparse_cu12-12.5.4.2-py3-none-manylinux2014_x86_64.manylinux_2_17_x86_64.whl (216.6 MB)
# - Creating objects...
# â””â”€â”€ ðŸ”¨ Created mount C:\Web Development\Projects\EchoVal AI\pricer_service.py
# \ Creating objects...
# â””â”€â”€ ðŸ”¨ Created mount C:\Web Development\Projects\EchoVal AI\pricer_service.py
# / Creating objects...
# â””â”€â”€ ðŸ”¨ Created mount C:\Web Development\Projects\EchoVal AI\pricer_service.py
# \ Creating objects...
# â””â”€â”€ ðŸ”¨ Created mount C:\Web Development\Projects\EchoVal AI\pricer_service.py
# / Creating objects...
# â””â”€â”€ ðŸ”¨ Created mount C:\Web Development\Projects\EchoVal AI\pricer_service.py
# / Creating objects...
# â””â”€â”€ ðŸ”¨ Created mount C:\Web Development\Projects\EchoVal AI\pricer_service.py
#    â”�â”�â”�â”�â”�â”�â”�â”�â”�â”�â”�â”�â”�â”�â”�â”�â”�â”�â”�â”�â”�â”�â”�â”�â”�â”�â”�â”�â”�â”�â”�â”�â”�â”�â”�â”�â”�â”�â”� 216.6/216.6 MB 231.4 MB/s eta 0:00:00
# - Creating objects...
# â””â”€â”€ ðŸ”¨ Created mount C:\Web Development\Projects\EchoVal AI\pricer_service.py
# Downloading http://pypi-mirror.modal.local:5555/simple/nvidia-cusparselt-cu12/nvidia_cusparselt_cu12-0.6.3-py3-none-manylinux2014_x86_64.whl (156.8 MB)
# - Creating objects...
# â””â”€â”€ ðŸ”¨ Created mount C:\Web Development\Projects\EchoVal AI\pricer_service.py
# \ Creating objects...
# â””â”€â”€ ðŸ”¨ Created mount C:\Web Development\Projects\EchoVal AI\pricer_service.py
# / Creating objects...
# â””â”€â”€ ðŸ”¨ Created mount C:\Web Development\Projects\EchoVal AI\pricer_service.py
# \ Creating objects...
# â””â”€â”€ ðŸ”¨ Created mount C:\Web Development\Projects\EchoVal AI\pricer_service.py
# | Creating objects...
# â””â”€â”€ ðŸ”¨ Created mount C:\Web Development\Projects\EchoVal AI\pricer_service.py
#    â”�â”�â”�â”�â”�â”�â”�â”�â”�â”�â”�â”�â”�â”�â”�â”�â”�â”�â”�â”�â”�â”�â”�â”�â”�â”�â”�â”�â”�â”�â”�â”�â”�â”�â”�â”�â”�â”�â”� 156.8/156.8 MB 195.7 MB/s eta 0:00:00
# | Creating objects...
# â””â”€â”€ ðŸ”¨ Created mount C:\Web Development\Projects\EchoVal AI\pricer_service.py
# Downloading http://pypi-mirror.modal.local:5555/simple/nvidia-nccl-cu12/nvidia_nccl_cu12-2.26.2-py3-none-manylinux2014_x86_64.manylinux_2_17_x86_64.whl (201.3 MB)
# | Creating objects...
# â””â”€â”€ ðŸ”¨ Created mount C:\Web Development\Projects\EchoVal AI\pricer_service.py
# / Creating objects...
# â””â”€â”€ ðŸ”¨ Created mount C:\Web Development\Projects\EchoVal AI\pricer_service.py
# \ Creating objects...
# â””â”€â”€ ðŸ”¨ Created mount C:\Web Development\Projects\EchoVal AI\pricer_service.py
# / Creating objects...
# â””â”€â”€ ðŸ”¨ Created mount C:\Web Development\Projects\EchoVal AI\pricer_service.py
# \ Creating objects...
# â””â”€â”€ ðŸ”¨ Created mount C:\Web Development\Projects\EchoVal AI\pricer_service.py
# \ Creating objects...
# â””â”€â”€ ðŸ”¨ Created mount C:\Web Development\Projects\EchoVal AI\pricer_service.py
#    â”�â”�â”�â”�â”�â”�â”�â”�â”�â”�â”�â”�â”�â”�â”�â”�â”�â”�â”�â”�â”�â”�â”�â”�â”�â”�â”�â”�â”�â”�â”�â”�â”�â”�â”�â”�â”�â”�â”� 201.3/201.3 MB 208.2 MB/s eta 0:00:00
# | Creating objects...
# â””â”€â”€ ðŸ”¨ Created mount C:\Web Development\Projects\EchoVal AI\pricer_service.py
# Downloading http://pypi-mirror.modal.local:5555/simple/nvidia-nvjitlink-cu12/nvidia_nvjitlink_cu12-12.6.85-py3-none-manylinux2010_x86_64.manylinux_2_12_x86_64.whl (19.7 MB)
# | Creating objects...
# â””â”€â”€ ðŸ”¨ Created mount C:\Web Development\Projects\EchoVal AI\pricer_service.py
# | Creating objects...
# â””â”€â”€ ðŸ”¨ Created mount C:\Web Development\Projects\EchoVal AI\pricer_service.py
#    â”�â”�â”�â”�â”�â”�â”�â”�â”�â”�â”�â”�â”�â”�â”�â”�â”�â”�â”�â”�â”�â”�â”�â”�â”�â”�â”�â”�â”�â”�â”�â”�â”�â”�â”�â”�â”�â”�â”�â”� 19.7/19.7 MB 191.2 MB/s eta 0:00:00
# / Creating objects...
# â””â”€â”€ ðŸ”¨ Created mount C:\Web Development\Projects\EchoVal AI\pricer_service.py
# Downloading http://pypi-mirror.modal.local:5555/simple/nvidia-nvtx-cu12/nvidia_nvtx_cu12-12.6.77-py3-none-manylinux2014_x86_64.manylinux_2_17_x86_64.whl (89 kB)
# / Creating objects...
# â””â”€â”€ ðŸ”¨ Created mount C:\Web Development\Projects\EchoVal AI\pricer_service.py
# Downloading http://pypi-mirror.modal.local:5555/simple/triton/triton-3.3.0-cp311-cp311-manylinux_2_27_x86_64.manylinux_2_28_x86_64.whl (156.5 MB)
# / Creating objects...
# â””â”€â”€ ðŸ”¨ Created mount C:\Web Development\Projects\EchoVal AI\pricer_service.py
# / Creating objects...
# â””â”€â”€ ðŸ”¨ Created mount C:\Web Development\Projects\EchoVal AI\pricer_service.py
# \ Creating objects...
# â””â”€â”€ ðŸ”¨ Created mount C:\Web Development\Projects\EchoVal AI\pricer_service.py
# / Creating objects...
# â””â”€â”€ ðŸ”¨ Created mount C:\Web Development\Projects\EchoVal AI\pricer_service.py
# - Creating objects...
# â””â”€â”€ ðŸ”¨ Created mount C:\Web Development\Projects\EchoVal AI\pricer_service.py
#    â”�â”�â”�â”�â”�â”�â”�â”�â”�â”�â”�â”�â”�â”�â”�â”�â”�â”�â”�â”�â”�â”�â”�â”�â”�â”�â”�â”�â”�â”�â”�â”�â”�â”�â”�â”�â”�â”�â”� 156.5/156.5 MB 201.6 MB/s eta 0:00:00
# \ Creating objects...
# â””â”€â”€ ðŸ”¨ Created mount C:\Web Development\Projects\EchoVal AI\pricer_service.py
# Downloading http://pypi-mirror.modal.local:5555/simple/transformers/transformers-4.52.3-py3-none-any.whl (10.5 MB)
# \ Creating objects...
# â””â”€â”€ ðŸ”¨ Created mount C:\Web Development\Projects\EchoVal AI\pricer_service.py
# \ Creating objects...
# â””â”€â”€ ðŸ”¨ Created mount C:\Web Development\Projects\EchoVal AI\pricer_service.py
#    â”�â”�â”�â”�â”�â”�â”�â”�â”�â”�â”�â”�â”�â”�â”�â”�â”�â”�â”�â”�â”�â”�â”�â”�â”�â”�â”�â”�â”�â”�â”�â”�â”�â”�â”�â”�â”�â”�â”�â”� 10.5/10.5 MB 219.1 MB/s eta 0:00:00
# \ Creating objects...
# â””â”€â”€ ðŸ”¨ Created mount C:\Web Development\Projects\EchoVal AI\pricer_service.py
# Downloading http://pypi-mirror.modal.local:5555/simple/huggingface-hub/huggingface_hub-0.32.2-py3-none-any.whl (509 kB)
# \ Creating objects...
# â””â”€â”€ ðŸ”¨ Created mount C:\Web Development\Projects\EchoVal AI\pricer_service.py
# Downloading http://pypi-mirror.modal.local:5555/simple/fsspec/fsspec-2025.5.1-py3-none-any.whl (199 kB)
# \ Creating objects...
# â””â”€â”€ ðŸ”¨ Created mount C:\Web Development\Projects\EchoVal AI\pricer_service.py
# \ Creating objects...
# â””â”€â”€ ðŸ”¨ Created mount C:\Web Development\Projects\EchoVal AI\pricer_service.py
# Downloading http://pypi-mirror.modal.local:5555/simple/numpy/numpy-2.2.6-cp311-cp311-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (16.8 MB)
# | Creating objects...
# â””â”€â”€ ðŸ”¨ Created mount C:\Web Development\Projects\EchoVal AI\pricer_service.py
# | Creating objects...
# â””â”€â”€ ðŸ”¨ Created mount C:\Web Development\Projects\EchoVal AI\pricer_service.py
#    â”�â”�â”�â”�â”�â”�â”�â”�â”�â”�â”�â”�â”�â”�â”�â”�â”�â”�â”�â”�â”�â”�â”�â”�â”�â”�â”�â”�â”�â”�â”�â”�â”�â”�â”�â”�â”�â”�â”�â”� 16.8/16.8 MB 190.9 MB/s eta 0:00:00
# | Creating objects...
# â””â”€â”€ ðŸ”¨ Created mount C:\Web Development\Projects\EchoVal AI\pricer_service.py
# Downloading http://pypi-mirror.modal.local:5555/simple/packaging/packaging-25.0-py3-none-any.whl (66 kB)
# | Creating objects...
# â””â”€â”€ ðŸ”¨ Created mount C:\Web Development\Projects\EchoVal AI\pricer_service.py
# Downloading http://pypi-mirror.modal.local:5555/simple/pyyaml/PyYAML-6.0.2-cp311-cp311-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (762 kB)
# | Creating objects...
# â””â”€â”€ ðŸ”¨ Created mount C:\Web Development\Projects\EchoVal AI\pricer_service.py
# / Creating objects...
# â””â”€â”€ ðŸ”¨ Created mount C:\Web Development\Projects\EchoVal AI\pricer_service.py
#    â”�â”�â”�â”�â”�â”�â”�â”�â”�â”�â”�â”�â”�â”�â”�â”�â”�â”�â”�â”�â”�â”�â”�â”�â”�â”�â”�â”�â”�â”�â”�â”�â”�â”�â”�â”�â”�â”�â”� 763.0/763.0 kB 354.8 MB/s eta 0:00:00
# / Creating objects...
# â””â”€â”€ ðŸ”¨ Created mount C:\Web Development\Projects\EchoVal AI\pricer_service.py
# Downloading http://pypi-mirror.modal.local:5555/simple/regex/regex-2024.11.6-cp311-cp311-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (792 kB)
# / Creating objects...
# â””â”€â”€ ðŸ”¨ Created mount C:\Web Development\Projects\EchoVal AI\pricer_service.py
# / Creating objects...
# â””â”€â”€ ðŸ”¨ Created mount C:\Web Development\Projects\EchoVal AI\pricer_service.py
#    â”�â”�â”�â”�â”�â”�â”�â”�â”�â”�â”�â”�â”�â”�â”�â”�â”�â”�â”�â”�â”�â”�â”�â”�â”�â”�â”�â”�â”�â”�â”�â”�â”�â”�â”�â”�â”�â”�â”� 792.7/792.7 kB 284.8 MB/s eta 0:00:00
# / Creating objects...
# â””â”€â”€ ðŸ”¨ Created mount C:\Web Development\Projects\EchoVal AI\pricer_service.py
# Downloading http://pypi-mirror.modal.local:5555/simple/safetensors/safetensors-0.5.3-cp38-abi3-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (471 kB)
# / Creating objects...
# â””â”€â”€ ðŸ”¨ Created mount C:\Web Development\Projects\EchoVal AI\pricer_service.py
# Downloading http://pypi-mirror.modal.local:5555/simple/sympy/sympy-1.14.0-py3-none-any.whl (6.3 MB)
# / Creating objects...
# â””â”€â”€ ðŸ”¨ Created mount C:\Web Development\Projects\EchoVal AI\pricer_service.py
# / Creating objects...
# â””â”€â”€ ðŸ”¨ Created mount C:\Web Development\Projects\EchoVal AI\pricer_service.py
#    â”�â”�â”�â”�â”�â”�â”�â”�â”�â”�â”�â”�â”�â”�â”�â”�â”�â”�â”�â”�â”�â”�â”�â”�â”�â”�â”�â”�â”�â”�â”�â”�â”�â”�â”�â”�â”�â”�â”�â”� 6.3/6.3 MB 221.9 MB/s eta 0:00:00
# / Creating objects...
# â””â”€â”€ ðŸ”¨ Created mount C:\Web Development\Projects\EchoVal AI\pricer_service.py
# Downloading http://pypi-mirror.modal.local:5555/simple/tokenizers/tokenizers-0.21.1-cp39-abi3-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (3.0 MB)
# / Creating objects...
# â””â”€â”€ ðŸ”¨ Created mount C:\Web Development\Projects\EchoVal AI\pricer_service.py
# / Creating objects...
# â””â”€â”€ ðŸ”¨ Created mount C:\Web Development\Projects\EchoVal AI\pricer_service.py
#    â”�â”�â”�â”�â”�â”�â”�â”�â”�â”�â”�â”�â”�â”�â”�â”�â”�â”�â”�â”�â”�â”�â”�â”�â”�â”�â”�â”�â”�â”�â”�â”�â”�â”�â”�â”�â”�â”�â”�â”� 3.0/3.0 MB 282.7 MB/s eta 0:00:00
# / Creating objects...
# â””â”€â”€ ðŸ”¨ Created mount C:\Web Development\Projects\EchoVal AI\pricer_service.py
# / Creating objects...
# â””â”€â”€ ðŸ”¨ Created mount C:\Web Development\Projects\EchoVal AI\pricer_service.py
# Downloading http://pypi-mirror.modal.local:5555/simple/tqdm/tqdm-4.67.1-py3-none-any.whl (78 kB)
# - Creating objects...
# â””â”€â”€ ðŸ”¨ Created mount C:\Web Development\Projects\EchoVal AI\pricer_service.py
# Downloading http://pypi-mirror.modal.local:5555/simple/filelock/filelock-3.18.0-py3-none-any.whl (16 kB)
# - Creating objects...
# â””â”€â”€ ðŸ”¨ Created mount C:\Web Development\Projects\EchoVal AI\pricer_service.py
# Downloading http://pypi-mirror.modal.local:5555/simple/jinja2/jinja2-3.1.6-py3-none-any.whl (134 kB)
# - Creating objects...
# â””â”€â”€ ðŸ”¨ Created mount C:\Web Development\Projects\EchoVal AI\pricer_service.py
# Downloading http://pypi-mirror.modal.local:5555/simple/networkx/networkx-3.5-py3-none-any.whl (2.0 MB)
# - Creating objects...
# â””â”€â”€ ðŸ”¨ Created mount C:\Web Development\Projects\EchoVal AI\pricer_service.py
# - Creating objects...
# â””â”€â”€ ðŸ”¨ Created mount C:\Web Development\Projects\EchoVal AI\pricer_service.py
#    â”�â”�â”�â”�â”�â”�â”�â”�â”�â”�â”�â”�â”�â”�â”�â”�â”�â”�â”�â”�â”�â”�â”�â”�â”�â”�â”�â”�â”�â”�â”�â”�â”�â”�â”�â”�â”�â”�â”�â”� 2.0/2.0 MB 248.0 MB/s eta 0:00:00
# - Creating objects...
# â””â”€â”€ ðŸ”¨ Created mount C:\Web Development\Projects\EchoVal AI\pricer_service.py
# Downloading http://pypi-mirror.modal.local:5555/simple/psutil/psutil-7.0.0-cp36-abi3-manylinux_2_12_x86_64.manylinux2010_x86_64.manylinux_2_17_x86_64.manylinux2014_x86_64.whl (277 kB)
# - Creating objects...
# â””â”€â”€ ðŸ”¨ Created mount C:\Web Development\Projects\EchoVal AI\pricer_service.py
# Downloading http://pypi-mirror.modal.local:5555/simple/requests/requests-2.32.3-py3-none-any.whl (64 kB)
# - Creating objects...
# â””â”€â”€ ðŸ”¨ Created mount C:\Web Development\Projects\EchoVal AI\pricer_service.py
# Downloading http://pypi-mirror.modal.local:5555/simple/charset-normalizer/charset_normalizer-3.4.2-cp311-cp311-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (147 kB)
# - Creating objects...
# â””â”€â”€ ðŸ”¨ Created mount C:\Web Development\Projects\EchoVal AI\pricer_service.py
# Downloading http://pypi-mirror.modal.local:5555/simple/hf-xet/hf_xet-1.1.2-cp37-abi3-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (5.2 MB)
# - Creating objects...
# â””â”€â”€ ðŸ”¨ Created mount C:\Web Development\Projects\EchoVal AI\pricer_service.py
# - Creating objects...
# â””â”€â”€ ðŸ”¨ Created mount C:\Web Development\Projects\EchoVal AI\pricer_service.py
#    â”�â”�â”�â”�â”�â”�â”�â”�â”�â”�â”�â”�â”�â”�â”�â”�â”�â”�â”�â”�â”�â”�â”�â”�â”�â”�â”�â”�â”�â”�â”�â”�â”�â”�â”�â”�â”�â”�â”�â”� 5.2/5.2 MB 229.6 MB/s eta 0:00:00
# - Creating objects...
# â””â”€â”€ ðŸ”¨ Created mount C:\Web Development\Projects\EchoVal AI\pricer_service.py
# Downloading http://pypi-mirror.modal.local:5555/simple/markupsafe/MarkupSafe-3.0.2-cp311-cp311-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (23 kB)
# \ Creating objects...
# â””â”€â”€ ðŸ”¨ Created mount C:\Web Development\Projects\EchoVal AI\pricer_service.py
# Downloading http://pypi-mirror.modal.local:5555/simple/mpmath/mpmath-1.3.0-py3-none-any.whl (536 kB)
# \ Creating objects...
# â””â”€â”€ ðŸ”¨ Created mount C:\Web Development\Projects\EchoVal AI\pricer_service.py
#    â”�â”�â”�â”�â”�â”�â”�â”�â”�â”�â”�â”�â”�â”�â”�â”�â”�â”�â”�â”�â”�â”�â”�â”�â”�â”�â”�â”�â”�â”�â”�â”�â”�â”�â”�â”�â”�â”�â”� 536.2/536.2 kB 671.7 MB/s eta 0:00:00
# \ Creating objects...
# â””â”€â”€ ðŸ”¨ Created mount C:\Web Development\Projects\EchoVal AI\pricer_service.py
# Downloading http://pypi-mirror.modal.local:5555/simple/urllib3/urllib3-2.4.0-py3-none-any.whl (128 kB)
# \ Creating objects...
# â””â”€â”€ ðŸ”¨ Created mount C:\Web Development\Projects\EchoVal AI\pricer_service.py
# | Creating objects...
# â””â”€â”€ ðŸ”¨ Created mount C:\Web Development\Projects\EchoVal AI\pricer_service.py
# / Creating objects...
# â””â”€â”€ ðŸ”¨ Created mount C:\Web Development\Projects\EchoVal AI\pricer_service.py
# \ Creating objects...
# â””â”€â”€ ðŸ”¨ Created mount C:\Web Development\Projects\EchoVal AI\pricer_service.py
# - Creating objects...
# â””â”€â”€ ðŸ”¨ Created mount C:\Web Development\Projects\EchoVal AI\pricer_service.py
# | Creating objects...
# â””â”€â”€ ðŸ”¨ Created mount C:\Web Development\Projects\EchoVal AI\pricer_service.py
# - Creating objects...
# â””â”€â”€ ðŸ”¨ Created mount C:\Web Development\Projects\EchoVal AI\pricer_service.py
# | Creating objects...
# â””â”€â”€ ðŸ”¨ Created mount C:\Web Development\Projects\EchoVal AI\pricer_service.py
# - Creating objects...
# â””â”€â”€ ðŸ”¨ Created mount C:\Web Development\Projects\EchoVal AI\pricer_service.py
# | Creating objects...
# â””â”€â”€ ðŸ”¨ Created mount C:\Web Development\Projects\EchoVal AI\pricer_service.py
# - Creating objects...
# â””â”€â”€ ðŸ”¨ Created mount C:\Web Development\Projects\EchoVal AI\pricer_service.py
# | Creating objects...
# â””â”€â”€ ðŸ”¨ Created mount C:\Web Development\Projects\EchoVal AI\pricer_service.py
# - Creating objects...
# â””â”€â”€ ðŸ”¨ Created mount C:\Web Development\Projects\EchoVal AI\pricer_service.py
# | Creating objects...
# â””â”€â”€ ðŸ”¨ Created mount C:\Web Development\Projects\EchoVal AI\pricer_service.py
# - Creating objects...
# â””â”€â”€ ðŸ”¨ Created mount C:\Web Development\Projects\EchoVal AI\pricer_service.py
# | Creating objects...
# â””â”€â”€ ðŸ”¨ Created mount C:\Web Development\Projects\EchoVal AI\pricer_service.py
# - Creating objects...
# â””â”€â”€ ðŸ”¨ Created mount C:\Web Development\Projects\EchoVal AI\pricer_service.py
# | Creating objects...
# ...
# \ Creating objects...
# â””â”€â”€ ðŸ”¨ Created mount C:\Web Development\Projects\EchoVal AI\pricer_service.py
# / Creating objects...
# â””â”€â”€ ðŸ”¨ Created mount C:\Web Development\Projects\EchoVal AI\pricer_service.py
# \ Creating objects...
# â””â”€â”€ ðŸ”¨ Created mount C:\Web Development\Projects\EchoVal AI\pricer_service.py
# / Creating objects...
# â””â”€â”€ ðŸ”¨ Created mount C:\Web Development\Projects\EchoVal AI\pricer_service.py
# | Creating objects...
# â””â”€â”€ ðŸ”¨ Created mount C:\Web Development\Projects\EchoVal AI\pricer_service.py
# - Creating objects...
# â””â”€â”€ ðŸ”¨ Created mount C:\Web Development\Projects\EchoVal AI\pricer_service.py
# | Creating objects...
# â””â”€â”€ ðŸ”¨ Created mount C:\Web Development\Projects\EchoVal AI\pricer_service.py
# - Creating objects...
# â””â”€â”€ ðŸ”¨ Created mount C:\Web Development\Projects\EchoVal AI\pricer_service.py
# | Creating objects...
# â””â”€â”€ ðŸ”¨ Created mount C:\Web Development\Projects\EchoVal AI\pricer_service.py
# - Creating objects...
# â””â”€â”€ ðŸ”¨ Created mount C:\Web Development\Projects\EchoVal AI\pricer_service.py
# | Creating objects...
# â””â”€â”€ ðŸ”¨ Created mount C:\Web Development\Projects\EchoVal AI\pricer_service.py
# - Creating objects...
# â””â”€â”€ ðŸ”¨ Created mount C:\Web Development\Projects\EchoVal AI\pricer_service.py
# | Creating objects...
# â””â”€â”€ ðŸ”¨ Created mount C:\Web Development\Projects\EchoVal AI\pricer_service.py
# - Creating objects...
# â””â”€â”€ ðŸ”¨ Created mount C:\Web Development\Projects\EchoVal AI\pricer_service.py
# | Creating objects...
# â””â”€â”€ ðŸ”¨ Created mount C:\Web Development\Projects\EchoVal AI\pricer_service.py
# - Creating objects...
# â””â”€â”€ ðŸ”¨ Created mount C:\Web Development\Projects\EchoVal AI\pricer_service.py
# | Creating objects...
# â””â”€â”€ ðŸ”¨ Created mount C:\Web Development\Projects\EchoVal AI\pricer_service.py
# - Creating objects...
# â””â”€â”€ ðŸ”¨ Created mount C:\Web Development\Projects\EchoVal AI\pricer_service.py
# | Creating objects...
# â””â”€â”€ ðŸ”¨ Created mount C:\Web Development\Projects\EchoVal AI\pricer_service.py
# - Creating objects...
# â””â”€â”€ ðŸ”¨ Created mount C:\Web Development\Projects\EchoVal AI\pricer_service.py
# | Creating objects...
# â””â”€â”€ ðŸ”¨ Created mount C:\Web Development\Projects\EchoVal AI\pricer_service.py
# - Creating objects...
# â””â”€â”€ ðŸ”¨ Created mount C:\Web Development\Projects\EchoVal AI\pricer_service.py
# | Creating objects...
# â””â”€â”€ ðŸ”¨ Created mount C:\Web Development\Projects\EchoVal AI\pricer_service.py
# - Creating objects...
# â””â”€â”€ ðŸ”¨ Created mount C:\Web Development\Projects\EchoVal AI\pricer_service.py
# | Creating objects...
# â””â”€â”€ ðŸ”¨ Created mount C:\Web Development\Projects\EchoVal AI\pricer_service.py
# - Creating objects...
# â””â”€â”€ ðŸ”¨ Created mount C:\Web Development\Projects\EchoVal AI\pricer_service.py
# | Creating objects...
# â””â”€â”€ ðŸ”¨ Created mount C:\Web Development\Projects\EchoVal AI\pricer_service.py
# - Creating objects...
# â””â”€â”€ ðŸ”¨ Created mount C:\Web Development\Projects\EchoVal AI\pricer_service.py
# | Creating objects...
# â””â”€â”€ ðŸ”¨ Created mount C:\Web Development\Projects\EchoVal AI\pricer_service.py
# - Creating objects...
# â””â”€â”€ ðŸ”¨ Created mount C:\Web Development\Projects\EchoVal AI\pricer_service.py
# | Creating objects...
# â””â”€â”€ ðŸ”¨ Created mount C:\Web Development\Projects\EchoVal AI\pricer_service.py
# - Creating objects...
# â””â”€â”€ ðŸ”¨ Created mount C:\Web Development\Projects\EchoVal AI\pricer_service.py
# | Creating objects...
# â””â”€â”€ ðŸ”¨ Created mount C:\Web Development\Projects\EchoVal AI\pricer_service.py
# - Creating objects...
# â””â”€â”€ ðŸ”¨ Created mount C:\Web Development\Projects\EchoVal AI\pricer_service.py
# | Creating objects...
# â””â”€â”€ ðŸ”¨ Created mount C:\Web Development\Projects\EchoVal AI\pricer_service.py
# - Creating objects...
# â””â”€â”€ ðŸ”¨ Created mount C:\Web Development\Projects\EchoVal AI\pricer_service.py
# | Creating objects...
# â””â”€â”€ ðŸ”¨ Created mount C:\Web Development\Projects\EchoVal AI\pricer_service.py
# - Creating objects...
# â””â”€â”€ ðŸ”¨ Created mount C:\Web Development\Projects\EchoVal AI\pricer_service.py
# | Creating objects...
# â””â”€â”€ ðŸ”¨ Created mount C:\Web Development\Projects\EchoVal AI\pricer_service.py
# - Creating objects...
# â””â”€â”€ ðŸ”¨ Created mount C:\Web Development\Projects\EchoVal AI\pricer_service.py
# | Creating objects...
# â””â”€â”€ ðŸ”¨ Created mount C:\Web Development\Projects\EchoVal AI\pricer_service.py
# \ Creating objects...
# â””â”€â”€ ðŸ”¨ Created mount C:\Web Development\Projects\EchoVal AI\pricer_service.py
# | Creating objects...
# â””â”€â”€ ðŸ”¨ Created mount C:\Web Development\Projects\EchoVal AI\pricer_service.py
# - Creating objects...
# â””â”€â”€ ðŸ”¨ Created mount C:\Web Development\Projects\EchoVal AI\pricer_service.py
# / Creating objects...
# â””â”€â”€ ðŸ”¨ Created mount C:\Web Development\Projects\EchoVal AI\pricer_service.py
# \ Creating objects...
# â””â”€â”€ ðŸ”¨ Created mount C:\Web Development\Projects\EchoVal AI\pricer_service.py
# / Creating objects...
# â””â”€â”€ ðŸ”¨ Created mount C:\Web Development\Projects\EchoVal AI\pricer_service.py
# \ Creating objects...
# â””â”€â”€ ðŸ”¨ Created mount C:\Web Development\Projects\EchoVal AI\pricer_service.py
# Successfully installed MarkupSafe-3.0.2 accelerate-1.7.0 bitsandbytes-0.46.0 charset-normalizer-3.4.2 filelock-3.18.0 fsspec-2025.5.1 hf-xet-1.1.2 huggingface-0.0.1 huggingface-hub-0.32.2 jinja2-3.1.6 mpmath-1.3.0 networkx-3.5 numpy-2.2.6 nvidia-cublas-cu12-12.6.4.1 nvidia-cuda-cupti-cu12-12.6.80 nvidia-cuda-nvrtc-cu12-12.6.77 nvidia-cuda-runtime-cu12-12.6.77 nvidia-cudnn-cu12-9.5.1.17 nvidia-cufft-cu12-11.3.0.4 nvidia-cufile-cu12-1.11.1.6 nvidia-curand-cu12-10.3.7.77 nvidia-cusolver-cu12-11.7.1.2 nvidia-cusparse-cu12-12.5.4.2 nvidia-cusparselt-cu12-0.6.3 nvidia-nccl-cu12-2.26.2 nvidia-nvjitlink-cu12-12.6.85 nvidia-nvtx-cu12-12.6.77 packaging-25.0 peft-0.15.2 psutil-7.0.0 pyyaml-6.0.2 regex-2024.11.6 requests-2.32.3 safetensors-0.5.3 sympy-1.14.0 tokenizers-0.21.1 torch-2.7.0 tqdm-4.67.1 transformers-4.52.3 triton-3.3.0 urllib3-2.4.0
# \ Creating objects...
# â””â”€â”€ ðŸ”¨ Created mount C:\Web Development\Projects\EchoVal AI\pricer_service.py
#
# [notice] A new release of pip is available: 24.3.1 -> 25.1.1
# [notice] To update, run: pip install --upgrade pip
# | Creating objects...
# â””â”€â”€ ðŸ”¨ Created mount C:\Web Development\Projects\EchoVal AI\pricer_service.py
# / Creating objects...
# â””â”€â”€ ðŸ”¨ Created mount C:\Web Development\Projects\EchoVal AI\pricer_service.py
# \ Creating objects...
# â””â”€â”€ ðŸ”¨ Created mount C:\Web Development\Projects\EchoVal AI\pricer_service.py
# / Creating objects...
# â””â”€â”€ ðŸ”¨ Created mount C:\Web Development\Projects\EchoVal AI\pricer_service.py
# \ Creating objects...
# â””â”€â”€ ðŸ”¨ Created mount C:\Web Development\Projects\EchoVal AI\pricer_service.py
# / Creating objects...
# â””â”€â”€ ðŸ”¨ Created mount C:\Web Development\Projects\EchoVal AI\pricer_service.py
# \ Creating objects...
# â””â”€â”€ ðŸ”¨ Created mount C:\Web Development\Projects\EchoVal AI\pricer_service.py
# / Creating objects...
# â””â”€â”€ ðŸ”¨ Created mount C:\Web Development\Projects\EchoVal AI\pricer_service.py
# Saving image...
# / Creating objects...
# â””â”€â”€ ðŸ”¨ Created mount C:\Web Development\Projects\EchoVal AI\pricer_service.py
# \ Creating objects...
# â””â”€â”€ ðŸ”¨ Created mount C:\Web Development\Projects\EchoVal AI\pricer_service.py
# / Creating objects...
# â””â”€â”€ ðŸ”¨ Created mount C:\Web Development\Projects\EchoVal AI\pricer_service.py
# \ Creating objects...
# â””â”€â”€ ðŸ”¨ Created mount C:\Web Development\Projects\EchoVal AI\pricer_service.py
# / Creating objects...
# â””â”€â”€ ðŸ”¨ Created mount C:\Web Development\Projects\EchoVal AI\pricer_service.py
# \ Creating objects...
# â””â”€â”€ ðŸ”¨ Created mount C:\Web Development\Projects\EchoVal AI\pricer_service.py
# / Creating objects...
# â””â”€â”€ ðŸ”¨ Created mount C:\Web Development\Projects\EchoVal AI\pricer_service.py
# \ Creating objects...
# â””â”€â”€ ðŸ”¨ Created mount C:\Web Development\Projects\EchoVal AI\pricer_service.py
# / Creating objects...
# â””â”€â”€ ðŸ”¨ Created mount C:\Web Development\Projects\EchoVal AI\pricer_service.py
# \ Creating objects...
# â””â”€â”€ ðŸ”¨ Created mount C:\Web Development\Projects\EchoVal AI\pricer_service.py
# / Creating objects...
# â””â”€â”€ ðŸ”¨ Created mount C:\Web Development\Projects\EchoVal AI\pricer_service.py
# \ Creating objects...
# â””â”€â”€ ðŸ”¨ Created mount C:\Web Development\Projects\EchoVal AI\pricer_service.py
# / Creating objects...
# â””â”€â”€ ðŸ”¨ Created mount C:\Web Development\Projects\EchoVal AI\pricer_service.py
# \ Creating objects...
# â””â”€â”€ ðŸ”¨ Created mount C:\Web Development\Projects\EchoVal AI\pricer_service.py
# / Creating objects...
# â””â”€â”€ ðŸ”¨ Created mount C:\Web Development\Projects\EchoVal AI\pricer_service.py
# \ Creating objects...
# â””â”€â”€ ðŸ”¨ Created mount C:\Web Development\Projects\EchoVal AI\pricer_service.py
# / Creating objects...
# â””â”€â”€ ðŸ”¨ Created mount C:\Web Development\Projects\EchoVal AI\pricer_service.py
# \ Creating objects...
# â””â”€â”€ ðŸ”¨ Created mount C:\Web Development\Projects\EchoVal AI\pricer_service.py
# / Creating objects...
# â””â”€â”€ ðŸ”¨ Created mount C:\Web Development\Projects\EchoVal AI\pricer_service.py
# \ Creating objects...
# â””â”€â”€ ðŸ”¨ Created mount C:\Web Development\Projects\EchoVal AI\pricer_service.py
# / Creating objects...
# â””â”€â”€ ðŸ”¨ Created mount C:\Web Development\Projects\EchoVal AI\pricer_service.py
# \ Creating objects...
# â””â”€â”€ ðŸ”¨ Created mount C:\Web Development\Projects\EchoVal AI\pricer_service.py
# Uploading image snapshotâ€¦ ---------------------------------  5.9/5.9 GB 0:00:00
# / Creating objects...
# â””â”€â”€ ðŸ”¨ Created mount C:\Web Development\Projects\EchoVal AI\pricer_service.py
# \ Creating objects...
# â””â”€â”€ ðŸ”¨ Created mount C:\Web Development\Projects\EchoVal AI\pricer_service.py
# / Creating objects...
# â””â”€â”€ ðŸ”¨ Created mount C:\Web Development\Projects\EchoVal AI\pricer_service.py
# \ Creating objects...
# â””â”€â”€ ðŸ”¨ Created mount C:\Web Development\Projects\EchoVal AI\pricer_service.py
# / Creating objects...
# â””â”€â”€ ðŸ”¨ Created mount C:\Web Development\Projects\EchoVal AI\pricer_service.py
# \ Creating objects...
# â””â”€â”€ ðŸ”¨ Created mount C:\Web Development\Projects\EchoVal AI\pricer_service.py
# / Creating objects...
# â””â”€â”€ ðŸ”¨ Created mount C:\Web Development\Projects\EchoVal AI\pricer_service.py
# \ Creating objects...
# â””â”€â”€ ðŸ”¨ Created mount C:\Web Development\Projects\EchoVal AI\pricer_service.py
# / Creating objects...
# â””â”€â”€ ðŸ”¨ Created mount C:\Web Development\Projects\EchoVal AI\pricer_service.py
# \ Creating objects...
# â””â”€â”€ ðŸ”¨ Created mount C:\Web Development\Projects\EchoVal AI\pricer_service.py
# / Creating objects...
# â””â”€â”€ ðŸ”¨ Created mount C:\Web Development\Projects\EchoVal AI\pricer_service.py
# | Creating objects...
# â””â”€â”€ ðŸ”¨ Created mount C:\Web Development\Projects\EchoVal AI\pricer_service.py
# - Creating objects...
# â””â”€â”€ ðŸ”¨ Created mount C:\Web Development\Projects\EchoVal AI\pricer_service.py
# | Creating objects...
# â””â”€â”€ ðŸ”¨ Created mount C:\Web Development\Projects\EchoVal AI\pricer_service.py
# - Creating objects...
# â””â”€â”€ ðŸ”¨ Created mount C:\Web Development\Projects\EchoVal AI\pricer_service.py
# | Creating objects...
# â””â”€â”€ ðŸ”¨ Created mount C:\Web Development\Projects\EchoVal AI\pricer_service.py
# - Creating objects...
# â””â”€â”€ ðŸ”¨ Created mount C:\Web Development\Projects\EchoVal AI\pricer_service.py
# | Creating objects...
# â””â”€â”€ ðŸ”¨ Created mount C:\Web Development\Projects\EchoVal AI\pricer_service.py
# - Creating objects...
# â””â”€â”€ ðŸ”¨ Created mount C:\Web Development\Projects\EchoVal AI\pricer_service.py
# | Creating objects...
# â””â”€â”€ ðŸ”¨ Created mount C:\Web Development\Projects\EchoVal AI\pricer_service.py
# - Creating objects...
# â””â”€â”€ ðŸ”¨ Created mount C:\Web Development\Projects\EchoVal AI\pricer_service.py
# | Creating objects...
# â””â”€â”€ ðŸ”¨ Created mount C:\Web Development\Projects\EchoVal AI\pricer_service.py
# - Creating objects...
# â””â”€â”€ ðŸ”¨ Created mount C:\Web Development\Projects\EchoVal AI\pricer_service.py
# Image saved, took 11.68s
# \ Creating objects...
# â””â”€â”€ ðŸ”¨ Created mount C:\Web Development\Projects\EchoVal AI\pricer_service.py
#
# Built image im-fehIzfbszjgZAuOZATuf0E in 111.47s
#
#
# \ Creating objects...
# â””â”€â”€ ðŸ”¨ Created mount C:\Web Development\Projects\EchoVal AI\pricer_service.py
# | Creating objects...
# â””â”€â”€ ðŸ”¨ Created mount C:\Web Development\Projects\EchoVal AI\pricer_service.py
# - Creating objects...
# â””â”€â”€ ðŸ”¨ Created mount C:\Web Development\Projects\EchoVal AI\pricer_service.py
# | Creating objects...
# â””â”€â”€ ðŸ”¨ Created mount C:\Web Development\Projects\EchoVal AI\pricer_service.py
# - Creating objects...
# â””â”€â”€ ðŸ”¨ Created mount C:\Web Development\Projects\EchoVal AI\pricer_service.py
# | Creating objects...
# â””â”€â”€ ðŸ”¨ Created mount C:\Web Development\Projects\EchoVal AI\pricer_service.py
# - Creating objects...
# â””â”€â”€ ðŸ”¨ Created mount C:\Web Development\Projects\EchoVal AI\pricer_service.py
# | Creating objects...
# â””â”€â”€ ðŸ”¨ Created mount C:\Web Development\Projects\EchoVal AI\pricer_service.py
# - Creating objects...
# â””â”€â”€ ðŸ”¨ Created mount C:\Web Development\Projects\EchoVal AI\pricer_service.py
# | Creating objects...
# â””â”€â”€ ðŸ”¨ Created mount C:\Web Development\Projects\EchoVal AI\pricer_service.py
# - Creating objects...
# â””â”€â”€ ðŸ”¨ Created mount C:\Web Development\Projects\EchoVal AI\pricer_service.py
# Building image im-ZJApx34HbL3Gza1DGmbz8M
# - Creating objects...
# â””â”€â”€ ðŸ”¨ Created mount C:\Web Development\Projects\EchoVal AI\pricer_service.py
#
# => Step 0: FROM base
# \ Creating objects...
# â””â”€â”€ ðŸ”¨ Created mount C:\Web Development\Projects\EchoVal AI\pricer_service.py
#
# => Step 1: ENV HF_HUB_CACHE=/cache
# \ Creating objects...
# â””â”€â”€ ðŸ”¨ Created mount C:\Web Development\Projects\EchoVal AI\pricer_service.py
# | Creating objects...
# â””â”€â”€ ðŸ”¨ Created mount C:\Web Development\Projects\EchoVal AI\pricer_service.py
# - Creating objects...
# â””â”€â”€ ðŸ”¨ Created mount C:\Web Development\Projects\EchoVal AI\pricer_service.py
# Saving image...
# | Creating objects...
# â””â”€â”€ ðŸ”¨ Created mount C:\Web Development\Projects\EchoVal AI\pricer_service.py
# | Creating objects...
# â””â”€â”€ ðŸ”¨ Created mount C:\Web Development\Projects\EchoVal AI\pricer_service.py
# - Creating objects...
# â””â”€â”€ ðŸ”¨ Created mount C:\Web Development\Projects\EchoVal AI\pricer_service.py
# | Creating objects...
# â””â”€â”€ ðŸ”¨ Created mount C:\Web Development\Projects\EchoVal AI\pricer_service.py
# Image saved, took 730.35ms
# - Creating objects...
# â””â”€â”€ ðŸ”¨ Created mount C:\Web Development\Projects\EchoVal AI\pricer_service.py
#
# Built image im-ZJApx34HbL3Gza1DGmbz8M in 1.77s
#
#
# - Creating objects...
# â””â”€â”€ ðŸ”¨ Created mount C:\Web Development\Projects\EchoVal AI\pricer_service.py
# - Creating objects...
# â””â”€â”€ ðŸ”¨ Created mount C:\Web Development\Projects\EchoVal AI\pricer_service.py
# / Creating objects...
# â”œâ”€â”€ ðŸ”¨ Created mount C:\Web Development\Projects\EchoVal AI\pricer_service.py
# â””â”€â”€ - Creating function Pricer.*...
# \ Creating objects...
# â”œâ”€â”€ ðŸ”¨ Created mount C:\Web Development\Projects\EchoVal AI\pricer_service.py
# â””â”€â”€ | Creating function Pricer.*...
# / Creating objects...
# â”œâ”€â”€ ðŸ”¨ Created mount C:\Web Development\Projects\EchoVal AI\pricer_service.py
# â””â”€â”€ ðŸ”¨ Created function Pricer.*.
# \ Creating objects...
# â”œâ”€â”€ ðŸ”¨ Created mount C:\Web Development\Projects\EchoVal AI\pricer_service.py
# â””â”€â”€ ðŸ”¨ Created function Pricer.*.
# \ Creating objects...
# â”œâ”€â”€ ðŸ”¨ Created mount C:\Web Development\Projects\EchoVal AI\pricer_service.py
# â””â”€â”€ ðŸ”¨ Created function Pricer.*.
#
# âœ“ Created objects.
# â”œâ”€â”€ ðŸ”¨ Created mount C:\Web Development\Projects\EchoVal AI\pricer_service.py
# â””â”€â”€ ðŸ”¨ Created function Pricer.*.
# âœ“ App deployed in 120.017s! ðŸŽ‰
#
# View Deployment:
# https://modal.com/apps/worksambhav26/main/deployed/pricer-service

# %%
Pricer = modal.Cls.from_name("pricer-service", "Pricer")
pricer = Pricer()
reply = pricer.price.remote("Quadcast HyperX condenser mic, connects via usb-c to your computer for crystal clear audio")
print(reply)
# Out:
# 139.9

# %%
from agents.special import SpecialistAgent

# %%
agent = SpecialistAgent()
agent.price("iPad Pro 2nd generation")
# Out:
# 729.0
